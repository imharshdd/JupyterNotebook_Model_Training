# %%
import numpy as np
import pandas as pd
import warnings
train_file = r'C:\Users\harsh\OneDrive\Desktop\train_data_set.csv'
test_file = r'C:\Users\harsh\OneDrive\Desktop\test_data_set.csv'
mt_train = pd.read_csv(train_file)
mt_test = pd.read_csv(test_file)

# %%
mt_train.columns.nunique()
mt_test.columns.nunique()
# Out:
# 11

# %%
mt_test.head()
# Out:
#                   created_at  entry_id   current    voltage  vibration  \
# 0  2022-04-05T13:30:41+05:30         1  2.223148  223.14752          0
# 1  2022-04-05T13:30:58+05:30         2  2.213905  224.07919          0
# 2  2022-04-05T13:31:14+05:30         3  2.333177  223.81500          0
# 3  2022-04-05T13:31:30+05:30         4  2.097085  224.11105          0
# 4  2022-04-05T13:31:47+05:30         5  2.249357  223.86400          0
#
#    temperature  latitude  longitude  relay_status  humidity  failure
# 0     37.36264       NaN        NaN             0        56      NaN
# 1     37.48474       NaN        NaN             0        56      NaN
# 2     37.60684       NaN        NaN             0        56      NaN
# 3     37.24054       NaN        NaN             0        56      NaN
# 4     37.36264       NaN        NaN             0        55      NaN

# %%
mt_train.head()
# Out:
#                   created_at  entry_id   current    voltage  vibration  \
# 0  2022-03-15T17:17:51+05:30         1  1.938089  238.64746          0
# 1  2022-03-15T17:18:07+05:30         2  2.352603  215.62500          0
# 2  2022-03-15T17:18:24+05:30         3  3.654926  152.06055          0
# 3  2022-03-15T17:18:41+05:30         4  2.420011  195.74707          0
# 4  2022-03-15T17:19:00+05:30         5  2.632627  177.10449          0
#
#    temperature  latitude  longitude  relay_status  humidity failure
# 0     37.11844       NaN        NaN             1        25     yes
# 1     37.36264       NaN        NaN             0        25      no
# 2     37.24054       NaN        NaN             0        46      no
# 3     37.11844       NaN        NaN             0        26      no
# 4     37.11844       NaN        NaN             0        26      no

# %%
mt_train['data']='train'
mt_test['data']='test'
mt_all = pd.concat([mt_train,mt_test],axis=0)
print(mt_train)
print(mt_test)
print(mt_all)
# Out:
#                     created_at  entry_id   current    voltage  vibration  \
# 0    2022-03-15T17:17:51+05:30         1  1.938089  238.64746          0
# 1    2022-03-15T17:18:07+05:30         2  2.352603  215.62500          0
# 2    2022-03-15T17:18:24+05:30         3  3.654926  152.06055          0
# 3    2022-03-15T17:18:41+05:30         4  2.420011  195.74707          0
# 4    2022-03-15T17:19:00+05:30         5  2.632627  177.10449          0
# ..                         ...       ...       ...        ...        ...
# 754  2022-04-05T13:29:20+05:30       755  2.452396  223.58131          0
# 755  2022-04-05T13:29:36+05:30       756  2.290720  223.07837          0
# 756  2022-04-05T13:29:52+05:30       757  2.190200  223.09837          0
# 757  2022-04-05T13:30:09+05:30       758  2.427122  222.83594          0
# 758  2022-04-05T13:30:25+05:30       759  1.913182  222.25797          0
#
#      temperature  latitude  longitude  relay_status  humidity failure   data
# 0       37.11844       NaN        NaN             1        25     yes  train
# 1       37.36264       NaN        NaN             0        25      no  train
# 2       37.24054       NaN        NaN             0        46      no  train
# 3       37.11844       NaN        NaN             0        26      no  train
# 4       37.11844       NaN        NaN             0        26      no  train
# ..           ...       ...        ...           ...       ...     ...    ...
# 754     37.48474       NaN        NaN             0        56      no  train
# 755     37.11844       NaN        NaN             0        56      no  train
# 756     37.72894       NaN        NaN             0        56      no  train
# 757     37.11844       NaN        NaN             0        56      no  train
# 758     37.97314       NaN        NaN             0        56      no  train
#
# [759 rows x 12 columns]
#                     created_at  entry_id   current    voltage  vibration  \
# 0    2022-04-05T13:30:41+05:30         1  2.223148  223.14752          0
# 1    2022-04-05T13:30:58+05:30         2  2.213905  224.07919          0
# 2    2022-04-05T13:31:14+05:30         3  2.333177  223.81500          0
# 3    2022-04-05T13:31:30+05:30         4  2.097085  224.11105          0
# 4    2022-04-05T13:31:47+05:30         5  2.249357  223.86400          0
# ..                         ...       ...       ...        ...        ...
# 188  2022-04-05T14:45:50+05:30       189  2.447289  211.85481          0
# 189  2022-04-05T14:46:06+05:30       190  2.425245  212.24246          0
# 190  2022-04-05T14:46:22+05:30       191  4.281932  238.45860          0
# 191  2022-04-05T14:46:38+05:30       192  3.826854  401.23560          0
# 192  2022-04-05T14:46:54+05:30       193  4.181952  250.38970          0
#
#      temperature  latitude  longitude  relay_status  humidity  failure  data
# 0       37.36264       NaN        NaN             0        56      NaN  test
# 1       37.48474       NaN        NaN             0        56      NaN  test
# 2       37.60684       NaN        NaN             0        56      NaN  test
# 3       37.24054       NaN        NaN             0        56      NaN  test
# 4       37.36264       NaN        NaN             0        55      NaN  test
# ..           ...       ...        ...           ...       ...      ...   ...
# 188     43.83394       NaN        NaN             0        33      NaN  test
# 189     44.07814       NaN        NaN             0        55      NaN  test
# 190     45.12915       NaN        NaN             1        56      NaN  test
# 191     47.26988       NaN        NaN             1        39      NaN  test
# 192     45.63972       NaN        NaN             1        53      NaN  test
#
# [193 rows x 12 columns]
#                     created_at  entry_id   current    voltage  vibration  \
# 0    2022-03-15T17:17:51+05:30         1  1.938089  238.64746          0
# 1    2022-03-15T17:18:07+05:30         2  2.352603  215.62500          0
# 2    2022-03-15T17:18:24+05:30         3  3.654926  152.06055          0
# 3    2022-03-15T17:18:41+05:30         4  2.420011  195.74707          0
# 4    2022-03-15T17:19:00+05:30         5  2.632627  177.10449          0
# ..                         ...       ...       ...        ...        ...
# 188  2022-04-05T14:45:50+05:30       189  2.447289  211.85481          0
# 189  2022-04-05T14:46:06+05:30       190  2.425245  212.24246          0
# 190  2022-04-05T14:46:22+05:30       191  4.281932  238.45860          0
# 191  2022-04-05T14:46:38+05:30       192  3.826854  401.23560          0
# 192  2022-04-05T14:46:54+05:30       193  4.181952  250.38970          0
#
#      temperature  latitude  longitude  relay_status  humidity failure   data
# 0       37.11844       NaN        NaN             1        25     yes  train
# 1       37.36264       NaN        NaN             0        25      no  train
# 2       37.24054       NaN        NaN             0        46      no  train
# 3       37.11844       NaN        NaN             0        26      no  train
# 4       37.11844       NaN        NaN             0        26      no  train
# ..           ...       ...        ...           ...       ...     ...    ...
# 188     43.83394       NaN        NaN             0        33     NaN   test
# 189     44.07814       NaN        NaN             0        55     NaN   test
# 190     45.12915       NaN        NaN             1        56     NaN   test
# 191     47.26988       NaN        NaN             1        39     NaN   test
# 192     45.63972       NaN        NaN             1        53     NaN   test
#
# [952 rows x 12 columns]

# %%
mt_all.nunique()
# Out:
# created_at      952
# entry_id        759
# current         952
# voltage         943
# vibration         2
# temperature     142
# latitude          0
# longitude         0
# relay_status      2
# humidity         37
# failure           2
# data              2
# dtype: int64

# %%
mt_all.head(900)
# Out:
#                     created_at  entry_id   current    voltage  vibration  \
# 0    2022-03-15T17:17:51+05:30         1  1.938089  238.64746          0
# 1    2022-03-15T17:18:07+05:30         2  2.352603  215.62500          0
# 2    2022-03-15T17:18:24+05:30         3  3.654926  152.06055          0
# 3    2022-03-15T17:18:41+05:30         4  2.420011  195.74707          0
# 4    2022-03-15T17:19:00+05:30         5  2.632627  177.10449          0
# ..                         ...       ...       ...        ...        ...
# 136  2022-04-05T14:31:27+05:30       137  2.250655  215.44836          0
# 137  2022-04-05T14:31:44+05:30       138  2.156489  214.47826          0
# 138  2022-04-05T14:32:00+05:30       139  2.405474  215.53758          0
# 139  2022-04-05T14:32:17+05:30       140  1.897152  214.30547          0
# 140  2022-04-05T14:32:33+05:30       141  2.025551  215.45250          0
#
#      temperature  latitude  longitude  relay_status  humidity failure   data
# 0       37.11844       NaN        NaN             1        25     yes  train
# 1       37.36264       NaN        NaN             0        25      no  train
# 2       37.24054       NaN        NaN             0        46      no  train
# 3       37.11844       NaN        NaN             0        26      no  train
# 4       37.11844       NaN        NaN             0        26      no  train
# ..           ...       ...        ...           ...       ...     ...    ...
# 136     41.02564       NaN        NaN             0        53     NaN   test
# 137     41.02564       NaN        NaN             0        53     NaN   test
# 138     41.02564       NaN        NaN             0        53     NaN   test
# 139     40.65934       NaN        NaN             0        53     NaN   test
# 140     41.39194       NaN        NaN             0        53     NaN   test
#
# [900 rows x 12 columns]

# %%
mt_all.drop(['created_at','entry_id','relay_status','longitude','latitude'],axis=1,inplace=True)
mt_all.head()
# Out:
#     current    voltage  vibration  temperature  humidity failure   data
# 0  1.938089  238.64746          0     37.11844        25     yes  train
# 1  2.352603  215.62500          0     37.36264        25      no  train
# 2  3.654926  152.06055          0     37.24054        46      no  train
# 3  2.420011  195.74707          0     37.11844        26      no  train
# 4  2.632627  177.10449          0     37.11844        26      no  train

# %%
mt_all['vibration']=(mt_all['vibration']==1).astype(int)
mt_all['vibration'].unique()
# Out:
# array([0, 1])

# %%
mt_all['failure']=(mt_all['failure']=='yes').astype(int)
#mt_all['failure']=pd.to_numeric(mt_all['failure'],errors='coerce')
mt_all['failure'].unique()
# Out:
# array([1, 0])

# %%
mt_all['failure'].unique()
mt_all['current'].unique()
# Out:
# array([ 1.93808893,  2.3526029 ,  3.65492562,  2.42001068,  2.63262665,
#         2.59451627,  2.12448554,  2.04803287,  4.60992094,  4.235678  ,
#         2.08533056,  2.19469373,  1.97518842,  2.15894051,  2.50941999,
#         2.33103632,  2.09349872,  2.26196897,  1.99534941,  2.47303572,
#         1.91732446,  2.29681498,  2.27597688,  1.93882104,  2.04027529,
#         2.3937268 ,  2.15540335,  2.11958207,  2.27313193,  1.93566008,
#         2.06922985,  2.31123551,  1.81772555,  2.43090333,  2.24741052,
#         1.85632882,  2.4191657 ,  1.84078027,  1.80799073,  2.24640308,
#         2.493824  ,  2.19469069,  2.21703484,  2.2741751 ,  1.82817298,
#         2.16897321,  2.41653386,  2.41504846,  1.85744896,  2.45333628,
#         2.04117258,  2.32832822,  2.38993846,  1.93252962,  2.28199638,
#         2.41192617,  2.02088826,  2.06830911,  1.83117423,  2.44387676,
#         2.00417072,  2.18353073,  1.91262391,  1.99866536,  2.30654065,
#         2.10062228,  1.99661252,  2.19162145,  2.19352985,  2.17482057,
#         1.83510502,  1.94154006,  2.07425171,  1.92113178,  2.19672131,
#         1.88196549,  2.54343827,  2.28330668,  2.14962754,  2.48502322,
#         2.01739394,  1.87976964,  2.20949977,  2.34320736,  2.467282  ,
#         1.89352361,  2.12303496,  1.93451587,  2.43712081,  1.96311885,
#         1.92782504,  2.4385614 ,  1.96210035,  1.95074618,  1.99932798,
#         2.31425113,  2.0512744 ,  2.25806871,  1.89637934,  2.1136962 ,
#         2.15180157,  2.19120433,  2.2683353 ,  2.12925006,  1.88812924,
#         2.25065533,  2.15648896,  2.40547379,  1.89715176,  2.02555087,
#         1.8415707 ,  1.93048033,  2.17385608,  1.85990993,  2.59307401,
#         2.02208327,  2.2611759 ,  1.90334454,  2.00461246,  2.03959443,
#         2.22013675,  2.11162675,  1.85877467,  1.84688795,  2.30092733,
#         2.05159223,  2.03180993,  1.94309263,  2.12313296,  2.43606524,
#         2.43238996,  1.98309003,  2.43233224,  2.22132987,  2.48931235,
#         1.89650249,  2.3088743 ,  2.12299544,  2.54638819,  2.41053937,
#         2.07309294,  2.18548684,  2.23655142,  2.1809931 ,  2.25024025,
#         2.52535285,  2.28880222,  2.20036825,  2.08119351,  1.93038195,
#         2.48863386,  2.3661077 ,  2.55487003,  2.01781396,  2.61737917,
#         2.09677871,  2.23300745,  2.44728925,  2.42524517,  4.281932  ,
#         3.826854  ,  4.181952  ])

# %%
for col in mt_all.columns:
    if col=='data' or mt_all[col].isnull().sum()==0:continue
    mt_all.loc[mt_all[col].isnull(),col]=mt_all.loc[mt_all['data']=='train',col].mean()
print(mt_all.head(900))
# Out:
#       current    voltage  vibration  temperature  humidity  failure   data
# 0    1.938089  238.64746          0     37.11844        25        1  train
# 1    2.352603  215.62500          0     37.36264        25        0  train
# 2    3.654926  152.06055          0     37.24054        46        0  train
# 3    2.420011  195.74707          0     37.11844        26        0  train
# 4    2.632627  177.10449          0     37.11844        26        0  train
# ..        ...        ...        ...          ...       ...      ...    ...
# 136  2.250655  215.44836          0     41.02564        53        0   test
# 137  2.156489  214.47826          0     41.02564        53        0   test
# 138  2.405474  215.53758          0     41.02564        53        0   test
# 139  1.897152  214.30547          0     40.65934        53        0   test
# 140  2.025551  215.45250          0     41.39194        53        0   test
#
# [900 rows x 7 columns]

# %%
mt_train = mt_all[mt_all['data']=='train']

del mt_train['data']



mt_test = mt_all[mt_all['data']=='test']

print(mt_test)



mt_test.drop(['data','failure'],axis=1,inplace=False)

print(mt_test)
# Out:
#       current    voltage  vibration  temperature  humidity  failure  data
# 0    2.223148  223.14752          0     37.36264        56        0  test
# 1    2.213905  224.07919          0     37.48474        56        0  test
# 2    2.333177  223.81500          0     37.60684        56        0  test
# 3    2.097085  224.11105          0     37.24054        56        0  test
# 4    2.249357  223.86400          0     37.36264        55        0  test
# ..        ...        ...        ...          ...       ...      ...   ...
# 188  2.447289  211.85481          0     43.83394        33        0  test
# 189  2.425245  212.24246          0     44.07814        55        0  test
# 190  4.281932  238.45860          0     45.12915        56        0  test
# 191  3.826854  401.23560          0     47.26988        39        0  test
# 192  4.181952  250.38970          0     45.63972        53        0  test
#
# [193 rows x 7 columns]
#       current    voltage  vibration  temperature  humidity  failure  data
# 0    2.223148  223.14752          0     37.36264        56        0  test
# 1    2.213905  224.07919          0     37.48474        56        0  test
# 2    2.333177  223.81500          0     37.60684        56        0  test
# 3    2.097085  224.11105          0     37.24054        56        0  test
# 4    2.249357  223.86400          0     37.36264        55        0  test
# ..        ...        ...        ...          ...       ...      ...   ...
# 188  2.447289  211.85481          0     43.83394        33        0  test
# 189  2.425245  212.24246          0     44.07814        55        0  test
# 190  4.281932  238.45860          0     45.12915        56        0  test
# 191  3.826854  401.23560          0     47.26988        39        0  test
# 192  4.181952  250.38970          0     45.63972        53        0  test
#
# [193 rows x 7 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
params = {'class_weight':['balanced'],'penalty':['l1','l2'],
         'C':np.linspace(0.0001,1000,10)}

# %%
model = LogisticRegression(fit_intercept=True,solver='lbfgs', max_iter=3000)

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(model,param_grid=params,cv=10,scoring='roc_auc',n_jobs=-1)

# %%
x_train = mt_train.drop('failure',axis=1)
y_train = mt_train['failure']

print(x_train)
print(y_train)
# Out:
#       current    voltage  vibration  temperature  humidity
# 0    1.938089  238.64746          0     37.11844        25
# 1    2.352603  215.62500          0     37.36264        25
# 2    3.654926  152.06055          0     37.24054        46
# 3    2.420011  195.74707          0     37.11844        26
# 4    2.632627  177.10449          0     37.11844        26
# ..        ...        ...        ...          ...       ...
# 754  2.452396  223.58131          0     37.48474        56
# 755  2.290720  223.07837          0     37.11844        56
# 756  2.190200  223.09837          0     37.72894        56
# 757  2.427122  222.83594          0     37.11844        56
# 758  1.913182  222.25797          0     37.97314        56
#
# [759 rows x 5 columns]
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 754    0
# 755    0
# 756    0
# 757    0
# 758    0
# Name: failure, Length: 759, dtype: int32

# %%
grid_search.fit(x_train,y_train)
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [       nan 0.82535887        nan 0.98152174        nan 0.98223602
#         nan 0.98271222        nan 0.98271222        nan 0.98271222
#         nan 0.98271222        nan 0.98271222        nan 0.98271222
#         nan 0.98271222]
#   warnings.warn(
# GridSearchCV(cv=10, estimator=LogisticRegression(max_iter=3000), n_jobs=-1,
#              param_grid={'C': array([1.000000e-04, 1.111112e+02, 2.222223e+02, 3.333334e+02,
#        4.444445e+02, 5.555556e+02, 6.666667e+02, 7.777778e+02,
#        8.888889e+02, 1.000000e+03]),
#                          'class_weight': ['balanced'],
#                          'penalty': ['l1', 'l2']},
#              scoring='roc_auc')

# %%
grid_search.best_estimator_
# Out:
# LogisticRegression(C=333.3334, class_weight='balanced', max_iter=3000)

# %%
mt_train['failure'].nunique()
grid_search.cv_results_
# Out:
# {'mean_fit_time': array([0.00102687, 0.0172116 , 0.00088763, 0.04241464, 0.00080051,
#         0.05550973, 0.00156243, 0.05501366, 0.00156236, 0.05799217,
#         0.00599656, 0.05616353, 0.        , 0.06155686, 0.00202382,
#         0.05742133, 0.00156248, 0.0640573 , 0.00236297, 0.07508271]),
#  'std_fit_time': array([0.00030477, 0.00242788, 0.00030182, 0.00747899, 0.00240154,
#         0.01553777, 0.00468729, 0.01705879, 0.00468707, 0.01618847,
#         0.01360117, 0.01278714, 0.        , 0.00470169, 0.00459365,
#         0.01826733, 0.00468743, 0.02099595, 0.0050233 , 0.0184654 ]),
#  'mean_score_time': array([0.        , 0.00384452, 0.        , 0.00156236, 0.        ,
#         0.0059516 , 0.        , 0.00309825, 0.        , 0.00453343,
#         0.        , 0.00598793, 0.        , 0.00403233, 0.        ,
#         0.00333815, 0.        , 0.00353243, 0.        , 0.00368559]),
#  'std_score_time': array([0.        , 0.00164984, 0.        , 0.00468707, 0.        ,
#         0.00965829, 0.        , 0.00551468, 0.        , 0.006971  ,
#         0.        , 0.00656263, 0.        , 0.00536398, 0.        ,
#         0.00513989, 0.        , 0.00484787, 0.        , 0.00077752]),
#  'param_C': masked_array(data=[0.0001, 0.0001, 111.11120000000001, 111.11120000000001,
#                     222.22230000000002, 222.22230000000002, 333.3334,
#                     333.3334, 444.4445, 444.4445, 555.5556, 555.5556,
#                     666.6667, 666.6667, 777.7778000000001,
#                     777.7778000000001, 888.8889, 888.8889, 1000.0, 1000.0],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_class_weight': masked_array(data=['balanced', 'balanced', 'balanced', 'balanced',
#                     'balanced', 'balanced', 'balanced', 'balanced',
#                     'balanced', 'balanced', 'balanced', 'balanced',
#                     'balanced', 'balanced', 'balanced', 'balanced',
#                     'balanced', 'balanced', 'balanced', 'balanced'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_penalty': masked_array(data=['l1', 'l2', 'l1', 'l2', 'l1', 'l2', 'l1', 'l2', 'l1',
#                     'l2', 'l1', 'l2', 'l1', 'l2', 'l1', 'l2', 'l1', 'l2',
#                     'l1', 'l2'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 0.0001, 'class_weight': 'balanced', 'penalty': 'l1'},
#   {'C': 0.0001, 'class_weight': 'balanced', 'penalty': 'l2'},
#   {'C': 111.11120000000001, 'class_weight': 'balanced', 'penalty': 'l1'},
#   {'C': 111.11120000000001, 'class_weight': 'balanced', 'penalty': 'l2'},
#   {'C': 222.22230000000002, 'class_weight': 'balanced', 'penalty': 'l1'},
#   {'C': 222.22230000000002, 'class_weight': 'balanced', 'penalty': 'l2'},
#   {'C': 333.3334, 'class_weight': 'balanced', 'penalty': 'l1'},
#   {'C': 333.3334, 'class_weight': 'balanced', 'penalty': 'l2'},
#   {'C': 444.4445, 'class_weight': 'balanced', 'penalty': 'l1'},
#   {'C': 444.4445, 'class_weight': 'balanced', 'penalty': 'l2'},
#   {'C': 555.5556, 'class_weight': 'balanced', 'penalty': 'l1'},
#   {'C': 555.5556, 'class_weight': 'balanced', 'penalty': 'l2'},
#   {'C': 666.6667, 'class_weight': 'balanced', 'penalty': 'l1'},
#   {'C': 666.6667, 'class_weight': 'balanced', 'penalty': 'l2'},
#   {'C': 777.7778000000001, 'class_weight': 'balanced', 'penalty': 'l1'},
#   {'C': 777.7778000000001, 'class_weight': 'balanced', 'penalty': 'l2'},
#   {'C': 888.8889, 'class_weight': 'balanced', 'penalty': 'l1'},
#   {'C': 888.8889, 'class_weight': 'balanced', 'penalty': 'l2'},
#   {'C': 1000.0, 'class_weight': 'balanced', 'penalty': 'l1'},
#   {'C': 1000.0, 'class_weight': 'balanced', 'penalty': 'l2'}],
#  'split0_test_score': array([       nan, 0.99585921,        nan, 0.99378882,        nan,
#         0.99378882,        nan, 0.99378882,        nan, 0.99378882,
#                nan, 0.99378882,        nan, 0.99378882,        nan,
#         0.99378882,        nan, 0.99378882,        nan, 0.99378882]),
#  'split1_test_score': array([nan,  1., nan,  1., nan,  1., nan,  1., nan,  1., nan,  1., nan,
#          1., nan,  1., nan,  1., nan,  1.]),
#  'split2_test_score': array([nan,  1., nan,  1., nan,  1., nan,  1., nan,  1., nan,  1., nan,
#          1., nan,  1., nan,  1., nan,  1.]),
#  'split3_test_score': array([       nan, 0.73809524,        nan, 1.        ,        nan,
#         1.        ,        nan, 1.        ,        nan, 1.        ,
#                nan, 1.        ,        nan, 1.        ,        nan,
#         1.        ,        nan, 1.        ,        nan, 1.        ]),
#  'split4_test_score': array([nan,  1., nan,  1., nan,  1., nan,  1., nan,  1., nan,  1., nan,
#          1., nan,  1., nan,  1., nan,  1.]),
#  'split5_test_score': array([       nan, 0.98571429,        nan, 1.        ,        nan,
#         1.        ,        nan, 1.        ,        nan, 1.        ,
#                nan, 1.        ,        nan, 1.        ,        nan,
#         1.        ,        nan, 1.        ,        nan, 1.        ]),
#  'split6_test_score': array([       nan, 0.98571429,        nan, 1.        ,        nan,
#         1.        ,        nan, 1.        ,        nan, 1.        ,
#                nan, 1.        ,        nan, 1.        ,        nan,
#         1.        ,        nan, 1.        ,        nan, 1.        ]),
#  'split7_test_score': array([nan,  1., nan,  1., nan,  1., nan,  1., nan,  1., nan,  1., nan,
#          1., nan,  1., nan,  1., nan,  1.]),
#  'split8_test_score': array([       nan, 0.50714286,        nan, 0.98809524,        nan,
#         0.9952381 ,        nan, 1.        ,        nan, 1.        ,
#                nan, 1.        ,        nan, 1.        ,        nan,
#         1.        ,        nan, 1.        ,        nan, 1.        ]),
#  'split9_test_score': array([       nan, 0.0410628 ,        nan, 0.83333333,        nan,
#         0.83333333,        nan, 0.83333333,        nan, 0.83333333,
#                nan, 0.83333333,        nan, 0.83333333,        nan,
#         0.83333333,        nan, 0.83333333,        nan, 0.83333333]),
#  'mean_test_score': array([       nan, 0.82535887,        nan, 0.98152174,        nan,
#         0.98223602,        nan, 0.98271222,        nan, 0.98271222,
#                nan, 0.98271222,        nan, 0.98271222,        nan,
#         0.98271222,        nan, 0.98271222,        nan, 0.98271222]),
#  'std_test_score': array([       nan, 0.30438346,        nan, 0.04954152,        nan,
#         0.04968244,        nan, 0.04982738,        nan, 0.04982738,
#                nan, 0.04982738,        nan, 0.04982738,        nan,
#         0.04982738,        nan, 0.04982738,        nan, 0.04982738]),
#  'rank_test_score': array([20, 10, 17,  9, 14,  8, 19,  1, 11,  1, 13,  1, 15,  1, 16,  1, 18,
#          1, 12,  1])}

# %%
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.6f} (std: {1:.6f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
report(grid_search.cv_results_,3)
# Out:
# Model with rank: 1
# Mean validation score: 0.982712 (std: 0.049827)
# Parameters: {'C': 333.3334, 'class_weight': 'balanced', 'penalty': 'l2'}
#
# Model with rank: 1
# Mean validation score: 0.982712 (std: 0.049827)
# Parameters: {'C': 444.4445, 'class_weight': 'balanced', 'penalty': 'l2'}
#
# Model with rank: 1
# Mean validation score: 0.982712 (std: 0.049827)
# Parameters: {'C': 555.5556, 'class_weight': 'balanced', 'penalty': 'l2'}
#
# Model with rank: 1
# Mean validation score: 0.982712 (std: 0.049827)
# Parameters: {'C': 666.6667, 'class_weight': 'balanced', 'penalty': 'l2'}
#
# Model with rank: 1
# Mean validation score: 0.982712 (std: 0.049827)
# Parameters: {'C': 777.7778000000001, 'class_weight': 'balanced', 'penalty': 'l2'}
#
# Model with rank: 1
# Mean validation score: 0.982712 (std: 0.049827)
# Parameters: {'C': 888.8889, 'class_weight': 'balanced', 'penalty': 'l2'}
#
# Model with rank: 1
# Mean validation score: 0.982712 (std: 0.049827)
# Parameters: {'C': 1000.0, 'class_weight': 'balanced', 'penalty': 'l2'}

# %%
print(mt_test)
test_prediction = grid_search.predict_proba(mt_test)
# Out:
#       current    voltage  vibration  temperature  humidity  failure  data
# 0    2.223148  223.14752          0     37.36264        56        0  test
# 1    2.213905  224.07919          0     37.48474        56        0  test
# 2    2.333177  223.81500          0     37.60684        56        0  test
# 3    2.097085  224.11105          0     37.24054        56        0  test
# 4    2.249357  223.86400          0     37.36264        55        0  test
# ..        ...        ...        ...          ...       ...      ...   ...
# 188  2.447289  211.85481          0     43.83394        33        0  test
# 189  2.425245  212.24246          0     44.07814        55        0  test
# 190  4.281932  238.45860          0     45.12915        56        0  test
# 191  3.826854  401.23560          0     47.26988        39        0  test
# 192  4.181952  250.38970          0     45.63972        53        0  test
#
# [193 rows x 7 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18832/2907987578.py in <module>
#       1 print(mt_test)
# ----> 2 test_prediction = grid_search.predict_proba(mt_test)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     118
#     119         # lambda, but not partial, allows help() to work with update_wrapper
# --> 120         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     121         # update the docstring of the returned function
#     122         update_wrapper(out, self.fn)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in predict_proba(self, X)
#     555         """
#     556         self._check_is_fitted('predict_proba')
# --> 557         return self.best_estimator_.predict_proba(X)
#     558
#     559     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in predict_proba(self, X)
#    1467                                                 self.solver == 'liblinear')))
#    1468         if ovr:
# -> 1469             return super()._predict_proba_lr(X)
#    1470         else:
#    1471             decision = self.decision_function(X)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _predict_proba_lr(self, X)
#     321         multiclass is handled by normalizing that over all classes.
#     322         """
# --> 323         prob = self.decision_function(X)
#     324         expit(prob, out=prob)
#     325         if prob.ndim == 1:
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     282         check_is_fitted(self)
#     283
# --> 284         X = check_array(X, accept_sparse='csr')
#     285
#     286         n_features = self.coef_.shape[1]
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'test'

# %%
test_prediction
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18832/3783047157.py in <module>
# ----> 1 test_prediction
#
# NameError: name 'test_prediction' is not defined

# %%
grid_search.classes_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1588/1694188889.py in <module>
# ----> 1 grid_search.classes_
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in classes_(self)
#     642     def classes_(self):
#     643         self._check_is_fitted("classes_")
# --> 644         return self.best_estimator_.classes_
#     645
#     646     def _run_search(self, evaluate_candidates):
#
# AttributeError: 'LogisticRegression' object has no attribute 'classes_'

# %%
train_score=grid_search.predict_proba(x_train)[:,1]
real = y_train
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1588/2517295020.py in <module>
# ----> 1 train_score=grid_search.predict_proba(x_train)[:,1]
#       2 real = y_train
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     118
#     119         # lambda, but not partial, allows help() to work with update_wrapper
# --> 120         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     121         # update the docstring of the returned function
#     122         update_wrapper(out, self.fn)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in predict_proba(self, X)
#     555         """
#     556         self._check_is_fitted('predict_proba')
# --> 557         return self.best_estimator_.predict_proba(X)
#     558
#     559     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in predict_proba(self, X)
#    1461             where classes are ordered as they are in ``self.classes_``.
#    1462         """
# -> 1463         check_is_fitted(self)
#    1464
#    1465         ovr = (self.multi_class in ["ovr", "warn"] or
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1096
#    1097     if not attrs:
# -> 1098         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1099
#    1100
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
cutoffs = np.linspace(.001,0.999, 999)

# %%
import seaborn as sns

# %%
 KS=[]

# %%
for cutoff in cutoffs:
 predicted=(train_score>cutoff).astype(int)
 TP=((real==1)&(predicted==1)).sum()
 FP=((real==0)&(predicted==1)).sum()
 TN=((real==0)&(predicted==0)).sum()
 FN=((real==1)&(predicted==0)).sum()
 
 ks=(TP/(TP+FN))-(FP/(TN+FP))
 KS.append(ks)

temp=pd.DataFrame({'cutoffs':cutoffs,'KS':KS})
sns.lmplot(x='cutoffs',y='KS',data=temp,fit_reg=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1588/2434743309.py in <module>
#       1 for cutoff in cutoffs:
# ----> 2  predicted=(train_score>cutoff).astype(int)
#       3  TP=((real==1)&(predicted==1)).sum()
#       4  FP=((real==0)&(predicted==1)).sum()
#       5  TN=((real==0)&(predicted==0)).sum()
#
# NameError: name 'train_score' is not defined

# %%
 ks
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1588/680807944.py in <module>
# ----> 1 ks
#
# NameError: name 'ks' is not defined

# %%
test_hard_classes=(test_prediction>cutoffs[KS==max(KS)][0]).astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1588/3465637157.py in <module>
# ----> 1 test_hard_classes=(test_prediction>cutoffs[KS==max(KS)][0]).astype(int)
#
# NameError: name 'test_prediction' is not defined

# %%
test_hard_classes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1588/3083070469.py in <module>
# ----> 1 test_hard_classes
#
# NameError: name 'test_hard_classes' is not defined

# %%
pd.DataFrame(test_hard_classes).to_csv("mysubmissionelogistic.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1588/2701474988.py in <module>
# ----> 1 pd.DataFrame(test_hard_classes).to_csv("mysubmissionelogistic.csv",index=False)
#
# NameError: name 'test_hard_classes' is not defined
